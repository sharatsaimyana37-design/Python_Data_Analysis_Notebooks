# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df.job_posted_date)

# %%
median_salary_year = df['salary_year_avg'].median()

# %%
median_salary_hour = df['salary_hour_avg'].median()

# %%
df_filled = df

df_filled['salary_year_avg'] = df_filled['salary_year_avg'].fillna(median_salary_year)
df_filled['salary_hour_avg'] = df_filled['salary_hour_avg'].fillna(median_salary_hour)

# %%
df_filled.loc[:, 'salary_year_avg':'salary_hour_avg']
# Out:
#         salary_year_avg  salary_hour_avg
# 0              115000.0            45.98
# 1              115000.0            45.98
# 2              115000.0            45.98
# 3              115000.0            45.98
# 4              115000.0            45.98
# ...                 ...              ...
# 785736         115000.0            45.98
# 785737         115000.0            45.98
# 785738         115000.0            45.98
# 785739         115000.0            45.98
# 785740         115000.0            45.98
#
# [785741 rows x 2 columns]

# %%
df_unique = df_filled
df_unique = df_unique.drop_duplicates()

print("Length of the dataset: ", len(df_filled))
print("Length of the duplicates: ", len(df_unique))
print("No. of duplicates: ", len(df_filled)-len(df_unique))
# Out:
# Length of the dataset:  785741
# Length of the duplicates:  785640
# No. of duplicates:  101

# %%
df_unique = df_unique.drop_duplicates(subset=['job_title', 'company_name'])

print("Length of the dataset: ", len(df_filled))
print("Length of the duplicates: ", len(df_unique))
print("No. of duplicates: ", len(df_filled)-len(df_unique))
# Out:
# Length of the dataset:  785741
# Length of the duplicates:  508042
# No. of duplicates:  277699
